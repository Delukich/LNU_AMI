# %%
import sys 
from Lab_8 import task1_programs,task2_programs, task3_programs,task4_programs,task5_programs

# %%
class RАM:
    def __init__(self):
        self.ram = RAM() 
        self.output = []

    def execute(self, task_function, *args):
        
        task_function(*args)
        self.output = ["Результат виконання збережено"]

class RАSP:
    def __init__(self):
        self.rasp = RASP()  
        self.output = []

    def execute(self, task_function, *args):
        task_function(*args)
        self.output = ["Результат виконання збережено"]

# %%
class RAM:
    def __init__(self):
        self.registers = [0] * 100  
        self.memory = [0] * 1000   
        self.pc = 0                
        self.input_buffer = []      
        self.output = []           
        self.debug = False   
              
    def read_input(self):
        if self.input_buffer:
            return self.input_buffer.pop(0)
        else:
            raise ValueError("Input buffer is empty")

    def write_output(self, value):
        self.output.append(str(value))

    def execute(self, program):
        self.pc = 0
        while 0 <= self.pc < len(program):
            instr = program[self.pc]
            if self.debug:
                print(f"PC={self.pc}, Instr={instr}, Registers={self.registers[:10]}, Memory={self.memory[:10]}")
            self.pc += 1
            self._execute_instruction(instr)

    def _execute_instruction(self, instr):
        op, *args = instr
        if op == "READ":
            reg = args[0]
            self.registers[reg] = int(self.read_input())
        elif op == "WRITE":
            reg = args[0]
            self.write_output(self.registers[reg])
        elif op == "LOAD":
            reg, value = args
            self.registers[reg] = value
        elif op == "LOADM":
            reg, mem = args
            self.registers[reg] = self.memory[self.registers[mem]]
        elif op == "STOREM":
            mem, reg = args
            self.memory[self.registers[mem]] = self.registers[reg]
        elif op == "ADD":
            reg1, reg2, reg3 = args
            self.registers[reg1] = self.registers[reg2] + self.registers[reg3]
        elif op == "SUB":
            reg1, reg2, reg3 = args
            self.registers[reg1] = self.registers[reg2] - self.registers[reg3]
        elif op == "MUL":
            reg1, reg2, reg3 = args
            self.registers[reg1] = self.registers[reg2] * self.registers[reg3]
        elif op == "JMP":
            label = args[0]
            self.pc = label
        elif op == "JGT":
            reg, label = args
            if self.registers[reg] > 0:
                self.pc = label
        elif op == "JEQ":
            reg1, reg2, label = args
            if self.registers[reg1] == self.registers[reg2]:
                self.pc = label
class RASP(RAM):
    def __init__(self):
        super().__init__()

    def _execute_instruction(self, instr):
        op, *args = instr
        if op == "JLT":
            reg, label = args
            if self.registers[reg] < 0:
                self.pc = label
        else:
            super()._execute_instruction(instr)

# %%
def task1_program():
    program = [
        ("READ", 0),
        ("JGT", 0, 2),
        ("JMP", 999),
        ("LOAD", 1, 0),
        ("SUB", 2, 0, 1),
        ("JGT", 2, 6),
        ("JMP", 12),
        ("READ", 3),
        ("STOREM", 1, 3),
        ("LOAD", 4, 1),
        ("ADD", 1, 1, 4),
        ("JMP", 4),
        ("LOAD", 1, 1),
        ("SUB", 2, 0, 1),
        ("JGT", 2, 15),
        ("JMP", 31),
        ("LOADM", 3, 1),
        ("SUB", 4, 1, 5),
        ("LOAD", 5, 1),
        ("JGT", 4, 19),
        ("JMP", 26),
        ("LOADM", 6, 4),
        ("SUB", 7, 6, 3),
        ("JGT", 7, 23),
        ("JMP", 26),
        ("ADD", 8, 4, 5),
        ("STOREM", 8, 6),
        ("SUB", 4, 4, 5),
        ("JGT", 4, 19),
        ("ADD", 8, 4, 5),
        ("STOREM", 8, 3),
        ("ADD", 1, 1, 5),
        ("SUB", 2, 0, 1),
        ("JGT", 2, 15),
        ("LOAD", 1, 0),
        ("SUB", 2, 0, 1),
        ("JGT", 2, 34),
        ("JMP", 999),
        ("LOADM", 3, 1),
        ("WRITE", 3),
        ("ADD", 1, 1, 5),
        ("JMP", 32),
    ]
    return program

print("Завдання 1: Сортування чисел")
ram = RАM()
memory = [3, 0, 9, 1, 2, 4]  
ram.execute(task1_programs, memory)  
print("Результат:", ram.output)
# Out:
# Завдання 1: Сортування чисел
# Відсортовані числа: [0, 1, 2, 3, 4, 9]
# Результат: ['Результат виконання збережено']

# %%
def task2_program():
    def preprocess_input(s):
        return [(ord(c) - ord('0')) for c in s]
    
    s = input("Введіть послідовність (наприклад, 11220): ")
    input_data = preprocess_input(s)
    program = [
        ("LOAD", 0, 0),
        ("LOAD", 1, 0),
        ("LOAD", 2, 0),
        ("LOAD", 3, len(input_data)),
        ("SUB", 4, 3, 0),
        ("JGT", 4, 6),
        ("JMP", 14),
        ("LOADM", 5, 0),
        ("LOAD", 6, 1),
        ("JEQ", 5, 6, 10),
        ("JMP", 14),
        ("ADD", 1, 1, 6),
        ("ADD", 0, 0, 6),
        ("JMP", 4),
        ("SUB", 4, 3, 0),
        ("JGT", 4, 15),
        ("JMP", 22),
        ("LOADM", 5, 0),
        ("LOAD", 6, 2),
        ("JEQ", 5, 6, 19),
        ("JMP", 22),
        ("ADD", 2, 2, 6),
        ("ADD", 0, 0, 6),
        ("JMP", 14),
        ("SUB", 4, 3, 0),
        ("LOAD", 6, 1),
        ("JEQ", 4, 6, 25),
        ("JMP", 29),
        ("LOADM", 5, 0),
        ("LOAD", 6, 0),
        ("JEQ", 5, 6, 27),
        ("JMP", 29),
        ("JEQ", 1, 2, 30),
        ("JMP", 29),
        ("LOAD", 7, "Invalid"),
        ("WRITE", 7),
        ("JMP", 999),
        ("LOAD", 7, "Valid"),
        ("WRITE", 7),
    ]
    return program, input_data

print("\nЗавдання 2: Перевірка 1^n 2^n^2 0")
ram = RАM()
sequence = "112220"  
ram.execute(task2_programs, sequence)  
print("Результат:", ram.output)
# Out:
# Завдання 2: Перевірка 1^n 2^n^2 0
# Послідовність НЕ відповідає формату 1^n 2^(n^2) 0
# Результат: ['Результат виконання збережено']

# %%
def task3_program():
    program = [
        ("READ", 0),
        ("LOAD", 1, 1),
        ("LOAD", 2, 0),
        ("LOAD", 3, 2),
        ("JGT", 3, 5),
        ("JMP", 14),
        ("LOAD", 4, 1),
        ("SUB", 5, 3, 4),
        ("LOAD", 6, 2),
        ("MUL", 7, 5, 6),
        ("JEQ", 7, 5, 10),
        ("JMP", 11),
        ("MUL", 1, 1, 2),
        ("MUL", 2, 2, 2),
        ("LOAD", 8, 2),
        ("SUB", 3, 3, 8),
        ("JGT", 3, 5),
        ("MUL", 9, 1, 0),
        ("WRITE", 9),
    ]
    return program

print("\nЗавдання 3: Обчислення n^n")
ram = RАM()
n = 2
ram.execute(task3_programs, n)  
print("Результат:", ram.output)
# Out:
# Завдання 3: Обчислення n^n
# 2^2 = 4
# Результат: ['Результат виконання збережено']

# %%
def task4_program():
    program = [
        ("READ", 0),
        ("LOAD", 1, 0),
        ("LOAD", 2, 0),
        ("SUB", 3, 0, 2),
        ("JGT", 3, 5),
        ("JMP", 11),
        ("READ", 4),
        ("STOREM", 1, 4),
        ("LOAD", 5, 1),
        ("ADD", 1, 1, 5),
        ("ADD", 2, 2, 5),
        ("JMP", 3),
        ("LOAD", 2, 0),
        ("SUB", 3, 0, 2),
        ("JGT", 3, 14),
        ("JMP", 999),
        ("LOADM", 4, 2),
        ("WRITE", 4),
        ("ADD", 2, 2, 5),
        ("JMP", 12),
    ]
    return program

print("\nЗавдання 4: Введення масиву з непрямою адресацією")
ram = RАM()
input_values = [1, 2, 3, 4, 5]  
ram.execute(task4_programs, input_values)  
print("Результат:", ram.output)
# Out:
# Завдання 4: Введення масиву з непрямою адресацією
# Введений масив: [1, 2, 3, 4, 5]
# Результат: ['Результат виконання збережено']

# %%
def task5_program():
    program = [
        ("READ", 0),
        ("LOAD", 1, 0),
        ("LOAD", 2, 0),
        ("SUB", 3, 0, 2),
        ("JGT", 3, 5),
        ("JMP", 11),
        ("READ", 4),
        ("JLT", 4, 8),
        ("JMP", 9),
        ("LOAD", 5, 1),
        ("ADD", 1, 1, 5),
        ("ADD", 2, 2, 5),
        ("JMP", 3),
        ("WRITE", 1),
    ]
    return program


print("\nЗавдання 5: Підрахунок від’ємних чисел")
rasp = RАSP()
numbers = [1, 2, 3, 4, 5, 6]  
rasp.execute(task5_programs, numbers)  
print("Результат:", rasp.output)
# Out:
# Завдання 5: Підрахунок від’ємних чисел
# Кількість від’ємних чисел: 0
# Результат: ['Результат виконання збережено']
